# %% [markdown]
# # Hello!
# This is Itay Peleg's interactive exam.
#
# Each question will have it's own block and you can run each block by clicking on it and clicking "> Run"

# %%
example_dictionary = {"Dani Vana":"0538827744", "Guy Elram":"0542138", "Yossi Levi":"0589946563", "Barak Gonen": "CyberCyber"}
def q1(dic):
    for name, pnum in dic.items():
        if len(pnum) == 10 and all([c.isdigit() for c in pnum]):
            print(name + " " + pnum[0:3] + "-" + pnum[3:6] + "-" + pnum[6:])

            
q1(example_dictionary)
# Out:
# Dani Vana 053-882-7744
# Yossi Levi 058-994-6563

# %%
import os
def q2a(filename):
    if os.path.exists(filename):
        with open(filename) as f:  # we can also call open(filename, "r") altough it is unnecessary
            pass
    else:
        print("This file does not exist, try again")

q2a("c:/temp/scores.txt")
# Out:
# This file does not exist, try again

# %%
def q2b(filename):
    if os.path.exists(filename):
        with open(filename) as f:
            print([[line] for line in f.readlines()])
        
    else:
        print("This file does not exist, try again")

# %%
def q4(score_tup):
    return (len(score_tup)==3 and score_tup[1]>=92 and score_tup[2]>=650) or \
           (len(score_tup)==2 and score_tup[1]>=96)

print(q4(("Itay Peleg", 100, 800)))
print(q4(("Itay Peleg", 90, 650)))
print(q4(("Itay Peleg", 95)))
print(q4(("Itay Peleg", 97)))
# Out:
# True
# False
# False
# True

# %%
q5a = lambda l1: [x for x in l1 if x>sum(l1)/len(l1)]

print(q5a([1,1,1,1,1]))
print(q5a([1,1,1,1,1,2]))
# Out:
# []
# [2]

# %%
q5b = lambda s: len([ss for ss in s.replace("\n", " ").split(" ") if ss != ""])

print(q5b("a s\gs \shdizv hkdh"))
print(q5b(""))
# Out:
# 4
# 0
